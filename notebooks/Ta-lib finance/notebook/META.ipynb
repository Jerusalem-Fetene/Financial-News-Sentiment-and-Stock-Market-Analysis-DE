# %%
import os
import sys
import pandas as pd
import yfinance as yf
import plotly as px

# %%
import sys
sys.path.append(r'C:\Users\ephre\Documents\Financial News and Stock Price Integration\Scripts')
from financial_analyzer import FinancialAnalyzer

# %%
file = r'C:\Users\ephre\Documents\Financial News and Stock Price Integration\data\yfinance_data\META_historical_data.csv'

# %%
fa = FinancialAnalyzer(file_path=file)

# %%
fa.calculate_technical_indicators()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-12-12   28.000000   28.139999   27.370001   27.580000   27.523441
# 2012-12-13   27.590000   28.750000   27.430000   28.240000   28.182087
# 2012-12-14   28.180000   28.330000   26.760000   26.809999   26.755020
# 2012-12-17   26.770000   27.000000   26.320000   26.750000   26.695143
# 2012-12-18   26.959999   27.910000   26.900000   27.709999   27.653173
# ...                ...         ...         ...         ...         ...
# 2024-07-24  472.309998  476.299988  460.579987  461.269989  461.269989
# 2024-07-25  463.260010  463.549988  442.649994  453.410004  453.410004
# 2024-07-26  464.200012  469.769989  459.420013  465.700012  465.700012
# 2024-07-29  469.880005  473.959991  465.019989  465.709991  465.709991
# 2024-07-30  467.000000  472.730011  456.700012  463.190002  463.190002
#
#               Volume  Dividends  Stock Splits         SMA        RSI  \
# Date
# 2012-12-12  46704200        0.0           0.0         NaN        NaN
# 2012-12-13  81051600        0.0           0.0         NaN        NaN
# 2012-12-14  91631600        0.0           0.0         NaN        NaN
# 2012-12-17  57742500        0.0           0.0         NaN        NaN
# 2012-12-18  60512900        0.0           0.0         NaN        NaN
# ...              ...        ...           ...         ...        ...
# 2024-07-24  17649700        0.0           0.0  502.223499  36.964279
# 2024-07-25  18240500        0.0           0.0  499.237999  34.814669
# 2024-07-26  14222400        0.0           0.0  496.545000  40.628601
# 2024-07-29  11339600        0.0           0.0  494.619499  40.633231
# 2024-07-30  11390400        0.0           0.0  492.545000  39.789373
#
#                    EMA       MACD  MACD_Signal
# Date
# 2012-12-12         NaN        NaN          NaN
# 2012-12-13         NaN        NaN          NaN
# 2012-12-14         NaN        NaN          NaN
# 2012-12-17         NaN        NaN          NaN
# 2012-12-18         NaN        NaN          NaN
# ...                ...        ...          ...
# 2024-07-24  493.134155  -6.550694    -1.274374
# 2024-07-25  489.350903  -8.810746    -2.781648
# 2024-07-26  487.098437  -9.500635    -4.125446
# 2024-07-29  485.061442  -9.932081    -5.286773
# 2024-07-30  482.978448 -10.357947    -6.301008
#
# [2926 rows x 13 columns]

# %%
fa.plot_stock_data()

# %%
fa.plot_rsi()

# %%
fa.plot_ema()

# %%
fa.plot_macd()
